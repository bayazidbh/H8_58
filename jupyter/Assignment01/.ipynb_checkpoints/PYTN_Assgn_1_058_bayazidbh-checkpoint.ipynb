# %%
### Download Dataset yang diperlukan dari kaggle di sini, lalu save ke folder /dataset.
### Buat Notebook baru, lalu rename menjadi “PYTN_Assgn_1_<batch_number>_<nama>".
### Lakukan Data Visualization kepada dataset seperti Line, Area, Scatter Plot, Box Plot, Word Clouds, Folium Maps dan metode Visualization Plot yang telah kamu pelajari di couse ini. Scroll ke bawah, ke bagian Project Rubric untuk melihat kriteria yang harus dipenuhi. Kamu dapat memilih kolom apa saja yang kamu inginkan.
### Kumpulkan informasi menggunakan analisis kamu.
### Area Plot	Mengimplementasikan Area Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik
### [Done] Histogram	Mengimplementasikan Histogram Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
### [Done] Bar Chart	Mengimplementasikan Bar Chart Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
### [Done] Pie Chart	Mengimplementasikan Pie Chart Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
### Box Plot	Mengimplementasikan Box Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
### Scatter Plot	Mengimplementasikan Scatter Plot Menggunakan `Matplotlib` Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
### [Done] Word Clouds	Mengimplementasikan Word Clouds Menggunakan `Wordclouds` Library Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik.
### [Done] Folium Maps	Mengimplementasikan London Maps Menggunakan `Folium`.
### Preprocessing	Student Melakukan Preproses Dataset Sebelum Menerapkan Visualisasi.
### Apakah Kode Berjalan Tanpa Ada Eror?	Seluruh Kode Berfungsi Dan Dibuat Dengan Benar.

# importing all libraries

import numpy as np
import pandas as pd
import folium
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from folium import plugins

# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches # needed for waffle Charts

mpl.style.use('ggplot') # optional: for ggplot-like style

print ('All modules loaded')
# Out:
# All modules loaded

# %%
df = pd.read_csv('2021-06-city-of-london-street.csv')
df
# Out:
#                                               Crime ID    Month  \
# 0                                                  NaN  2021-06
# 1    f0f8c98f14e0505abb6bc9e542e0f1f37f2cd6ef5b099b...  2021-06
# 2                                                  NaN  2021-06
# 3    9c93ff5c8cee3bde9224525f35b9f3c27e68acdec1e41b...  2021-06
# 4    f11c173771861690ba65a79fe7b492a5d4c547e98becf6...  2021-06
# ..                                                 ...      ...
# 565  3a6a36101e7c6b7a431c13756c017d23f6d020e586065e...  2021-06
# 566  21b27b130baafeae0a31ff73ed568c863f02bceed585cb...  2021-06
# 567  9da3d839603892a84e8ef0861ff36787b99bee1ca7c7e6...  2021-06
# 568  ae6e17dab724c47d8f6cc52f95179b645794b1544735a2...  2021-06
# 569  971a230ab1bc5ded6b5978d2675d31451119e595d290bc...  2021-06
#
#                Reported by           Falls within  Longitude   Latitude  \
# 0    City of London Police  City of London Police  -0.106453  51.518207
# ...

# %%
df.head()
# Out:
#                                             Crime ID    Month  \
# 0                                                NaN  2021-06
# 1  f0f8c98f14e0505abb6bc9e542e0f1f37f2cd6ef5b099b...  2021-06
# 2                                                NaN  2021-06
# 3  9c93ff5c8cee3bde9224525f35b9f3c27e68acdec1e41b...  2021-06
# 4  f11c173771861690ba65a79fe7b492a5d4c547e98becf6...  2021-06
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.106453  51.518207
# 1  City of London Police  City of London Police  -0.111962  51.518494
# 2  City of London Police  City of London Police  -0.095914  51.520348
# 3  City of London Police  City of London Police  -0.095892  51.516391
# 4  City of London Police  City of London Police  -0.095892  51.516391
#
#                          Location  LSOA code            LSOA name  \
# 0  On or near Charterhouse Street  E01000916          Camden 027B
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 570 entries, 409 to 0
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               471 non-null    object
#  1   Month                  570 non-null    object
#  2   Reported by            570 non-null    object
#  3   Falls within           570 non-null    object
#  4   Longitude              520 non-null    float64
#  5   Latitude               520 non-null    float64
#  6   Location               570 non-null    object
#  7   LSOA code              520 non-null    object
#  8   LSOA name              520 non-null    object
#  9   Crime type             570 non-null    object
#  10  Last outcome category  471 non-null    object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 57.9+ KB

# %%
## using Crime type for most of the operations, defining value shorthand

df_crime = df['Crime type'].value_counts()
df_crime
# Out:
# Anti-social behaviour           99
# Violence and sexual offences    91
# Shoplifting                     64
# Drugs                           63
# Public order                    56
# Other theft                     50
# Theft from the person           34
# Criminal damage and arson       29
# Other crime                     20
# Bicycle theft                   20
# Vehicle crime                   19
# Burglary                        10
# Robbery                         10
# Possession of weapons            5
# Name: Crime type, dtype: int64

# %%
df_crime.index
# Out:
# Index(['Anti-social behaviour', 'Violence and sexual offences', 'Shoplifting',
#        'Drugs', 'Public order', 'Other theft', 'Theft from the person',
#        'Criminal damage and arson', 'Other crime', 'Bicycle theft',
#        'Vehicle crime', 'Burglary', 'Robbery', 'Possession of weapons'],
#       dtype='object')

# %%
### Bar Chart for Amount of Crimes by Type
df_crime.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
### Bar Chart for Amount of Crimes by Type

df_crime.plot(kind='pie',
                            figsize=(16, 8),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.1,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            explode=[0, 0, 0, 0, 0, 0, 0, 0, 0.05, 0.07, 0.1, 0.15, 0.19, 0.27]
                                    )


plt.title('Reports by Crime Type for London in 2016', pad=20)
plt.axis('equal') # Sets the pie chart to look like a circle.
plt.legend(labels=df_crime.index, loc='upper left') 

plt.show()

# %%
## word cloud for word counting

crime_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df['Crime type']:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    crime_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(crime_words)
 
# plot the WordCloud image                      
fig = plt.figure()
fig.set_figwidth(20)
fig.set_figheight(10)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
## folium, checking for initial location

latitude = 51.5170923
longitude = -0.0909496
london_map = folium.Map(location=[latitude, longitude], zoom_start=12, tiles='Stamen Terrain')
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
# Prep for Folium
## Rename column for better reading, drop NaN in modified data

df_xy = df.rename(columns = {'Longitude':'X', 'Latitude':'Y'}, inplace = False)
df_xyd = df_xy.dropna(subset=['X', 'Y'])
df_xy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 570 entries, 409 to 0
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               471 non-null    object
#  1   Month                  570 non-null    object
#  2   Reported by            570 non-null    object
#  3   Falls within           570 non-null    object
#  4   X                      520 non-null    float64
#  5   Y                      520 non-null    float64
#  6   Location               570 non-null    object
#  7   LSOA code              520 non-null    object
#  8   LSOA name              520 non-null    object
#  9   Crime type             570 non-null    object
#  10  Last outcome category  471 non-null    object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 57.9+ KB

# %%
# folium
## adjust map zoom
latitude = 51.5170923
longitude = -0.0909496
london_map = folium.Map(location=[latitude, longitude], zoom_start=14.5, tiles='Stamen Terrain')
london_map

# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(df_xyd.Y, df_xyd.X):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(df_xyd.Y)
longitudes = list(df_xyd.X)
labels = list(df_xyd['Crime type'])

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(london_map)    
    
# add incidents to map
london_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
# testing for column names in value_counts

df_crime_columned = df_crime.reset_index()
df_crime_columned.columns = ['Crime', 'Count']
df_crime_columned
# Out:
#                            Crime  Count
# 0          Anti-social behaviour     99
# 1   Violence and sexual offences     91
# 2                    Shoplifting     64
# 3                          Drugs     63
# 4                   Public order     56
# 5                    Other theft     50
# 6          Theft from the person     34
# 7      Criminal damage and arson     29
# 8                    Other crime     20
# 9                  Bicycle theft     20
# 10                 Vehicle crime     19
# 11                      Burglary     10
# 12                       Robbery     10
# 13         Possession of weapons      5

# %%
# checking data type in created value_counts data

df_crime_columned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Crime   14 non-null     object
#  1   Count   14 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 352.0+ bytes

# %%
# use LSOA name for histogram

df_loc = df['LSOA name'].value_counts()
df_loc
# Out:
# City of London 001F    323
# City of London 001E     63
# City of London 001G     46
# City of London 001A     21
# Tower Hamlets 027B      17
# City of London 001B     16
# City of London 001C     10
# Tower Hamlets 015B       4
# Islington 023D           4
# Islington 022H           3
# Islington 023E           2
# Tower Hamlets 021D       2
# Hackney 025D             1
# Southwark 003H           1
# Westminster 018B         1
# Hackney 027G             1
# Camden 027B              1
# Camden 028B              1
# Tower Hamlets 021F       1
# Tower Hamlets 019C       1
# Islington 022D           1
# Name: LSOA name, dtype: int64

# %%
## defining columns for histogram

df_loc_columned = df_crime.reset_index()
df_loc_columned.columns = ['LSOA', 'Count']
df_loc_columned

# creating histogram
df_loc_columned['Count'].plot(kind='hist', figsize=(8, 5))


# histrogram legends
plt.title('Histogram of Crimes for each LSOA from 2021-06') # add a title to the histogram
plt.ylabel('Number of LSOA') # add y-label
plt.xlabel('Number of Crimes') # add x-label

plt.show()
